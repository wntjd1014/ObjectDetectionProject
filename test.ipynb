# %% [markdown]
# wakfjdkfjd

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
git init
# Out:
#   File "<ipython-input-3-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
$ git init
# Out:
#   File "<ipython-input-4-355ecfd3ecff>", line 1
#     $ git init
#     ^
# SyntaxError: invalid syntax

# %%
# !git add test.ipynb
# !git commit -m "Connect Google Colab and Drive"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git config --global user.email 'wntjd1014@gmail.com'
# !git config --global user.name 'wntjd1014'

# %%
# !git add test.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
cd /content/drive/MyDrive/Colab Notebooks/commit_folder/ObjectDetectionProject
# Out:
# /content/drive/MyDrive/Colab Notebooks/commit_folder/ObjectDetectionProject
